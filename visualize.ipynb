# %%
import aligner

# the tables are normalized by columns (each column sums to 1) to show how each intent is distributed on the frames

# %%
aligner.compute_alignment_matrix('botcycle')
# Out:
# /home/martino/kmi/open-sesame/annotation_playground/aligner.py:103: RuntimeWarning: invalid value encountered in true_divide
#   new_matrix = matrix / row_sums[:, np.newaxis]

# %%
aligner.compute_alignment_matrix('atis')

# %%
aligner.compute_alignment_matrix('nlu-benchmark')
