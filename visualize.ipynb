# %%
import aligner

# the tables are normalized by columns (each column sums to 1) to show how each intent is distributed on the frames

# %%
aligner.main('botcycle')
# Out:
# ask_position --> [('Performers_and_roles', 3.0), ('Locative_relation', 3.0), ('Negation', 3.0)]
# booking --> [('Operate_vehicle', 3.0), ('Locale_by_use', 2.0), ('Containers', 1.0)]
# city_supported --> [('Containers', 9.0), ('Taking_sides', 6.0), ('Using', 3.0)]
# end_discussion --> [('Using', 0.0), ('Desirability', 0.0), ('Judgment_direct_address', 0.0)]
# greeting --> [('Spatial_co-location', 4.0), ('Performers_and_roles', 1.0), ('Personal_relationship', 1.0)]
# info --> [('Likelihood', 5.0), ('People', 3.0), ('Performers_and_roles', 2.0)]
# plan_trip --> [('Locative_relation', 58.0), ('Desiring', 32.0), ('Goal', 18.0)]
# search_bike --> [('Operate_vehicle', 59.0), ('Sex', 12.0), ('Desiring', 9.0)]
# search_slot --> [('Operate_vehicle', 22.0), ('Locative_relation', 21.0), ('Departing', 16.0)]
# set_position --> [('Performers_and_roles', 63.0), ('Temporal_collocation', 47.0), ('Being_employed', 14.0)]
# thank --> [('Judgment_direct_address', 5.0), ('Desirability', 2.0), ('Degree', 2.0)]
# /home/martino/kmi/open-sesame/annotation_playground/aligner.py:113: RuntimeWarning: invalid value encountered in true_divide
#   new_matrix = matrix / row_sums[:, np.newaxis]

# %%
aligner.main('atis')
# Out:
# atis_abbreviation --> [('Entity', 81.0), ('Causation', 22.0), ('Evidence', 16.0)]
# atis_aircraft --> [('Vehicle', 53.0), ('Partitive', 32.0), ('Goal', 28.0)]
# atis_aircraft#atis_flight#atis_flight_no --> [('Architectural_part', 2.0), ('Goal', 2.0), ('Performers_and_roles', 2.0)]
# atis_airfare --> [('Goal', 250.0), ('Ammunition', 86.0), ('Locative_relation', 80.0)]
# atis_airline --> [('Goal', 51.0), ('Motion', 41.0), ('Have_associated', 30.0)]
# atis_airline#atis_flight_no --> [('Architectural_part', 2.0), ('Quantified_mass', 1.0), ('Judgment_direct_address', 1.0)]
# atis_airport --> [('Buildings', 15.0), ('Being_employed', 2.0), ('Text', 2.0)]
# atis_capacity --> [('Quantified_mass', 7.0), ('Entity', 3.0), ('Vehicle', 3.0)]
# atis_cheapest --> [('Temporal_collocation', 1.0), ('Differentiation', 0.0), ('Entity', 0.0)]
# atis_city --> [('Locative_relation', 5.0), ('Performers_and_roles', 5.0), ('Entity', 4.0)]
# atis_distance --> [('Buildings', 13.0), ('Goal', 8.0), ('Locale_by_use', 6.0)]
# atis_flight --> [('Architectural_part', 2125.0), ('Goal', 1722.0), ('Locative_relation', 1141.0)]
# atis_flight#atis_airfare --> [('Goal', 10.0), ('Locative_relation', 7.0), ('Ammunition', 5.0)]
# atis_flight_no --> [('Architectural_part', 10.0), ('Goal', 5.0), ('Quantified_mass', 3.0)]
# atis_flight_time --> [('Architectural_part', 24.0), ('Goal', 23.0), ('Entity', 16.0)]
# atis_ground_fare --> [('Proportional_quantity', 4.0), ('Entity', 4.0), ('Wearing', 3.0)]
# atis_ground_service --> [('Temporal_collocation', 74.0), ('Buildings', 71.0), ('Entity', 57.0)]
# atis_ground_service#atis_ground_fare --> [('Locative_relation', 1.0), ('Expensiveness', 1.0), ('Proportional_quantity', 1.0)]
# atis_meal --> [('Performers_and_roles', 3.0), ('Goal', 3.0), ('Architectural_part', 2.0)]
# atis_quantity --> [('Quantified_mass', 34.0), ('Performers_and_roles', 16.0), ('Have_associated', 15.0)]
# atis_restriction --> [('Performers_and_roles', 2.0), ('Cardinal_numbers', 1.0), ('Partitive', 1.0)]

# %%
aligner.main('nlu-benchmark')
# Out:
# AddToPlaylist --> [('Goal', 1056.0), ('Statement', 516.0), ('Locative_relation', 251.0)]
# BookRestaurant --> [('Being_employed', 648.0), ('Temporal_collocation', 608.0), ('Cardinal_numbers', 251.0)]
# GetWeather --> [('Temporal_collocation', 811.0), ('Performers_and_roles', 663.0), ('Weather', 333.0)]
# PlayMusic --> [('Performing_arts', 412.0), ('Means', 327.0), ('Competition', 273.0)]
# RateBook --> [('Age', 663.0), ('Cardinal_numbers', 578.0), ('Sex', 463.0)]
# SearchCreativeWork --> [('Age', 326.0), ('Locative_relation', 217.0), ('Goal', 166.0)]
# SearchScreeningEvent --> [('Being_employed', 482.0), ('Performers_and_roles', 351.0), ('Competition', 350.0)]

# %%
aligner.main('huric')
# Out:
# Being_in_category --> [('Building_subparts', 6.0), ('Sex', 3.0), ('Being_in_operation', 2.0)]
# Being_located --> [('Spatial_co-location', 10.0), ('Performers_and_roles', 7.0), ('Building_subparts', 7.0)]
# Bringing --> [('Goal', 46.0), ('Building_subparts', 31.0), ('Containers', 16.0)]
# Change_operational_state --> [('Being_in_operation', 17.0), ('Temporal_collocation', 8.0), ('Containers', 4.0)]
# Closure --> [('Body_movement', 9.0), ('Containers', 6.0), ('Closure', 5.0)]
# Entering --> [('Building_subparts', 4.0), ('Age', 1.0), ('Connecting_architecture', 1.0)]
# Following --> [('Relative_time', 30.0), ('People', 7.0), ('Goal', 4.0)]
# Giving --> [('Containers', 2.0), ('Sex', 2.0), ('Cardinal_numbers', 1.0)]
# Inspecting --> [('Inspecting', 5.0), ('Concessive', 5.0), ('Temporal_collocation', 2.0)]
# Motion --> [('Goal', 55.0), ('Building_subparts', 22.0), ('Cause_change_of_position_on_a_scale', 15.0)]
# Placing --> [('Being_in_operation', 21.0), ('Building_subparts', 4.0), ('Sex', 4.0)]
# Releasing --> [('Publishing', 2.0), ('Building_subparts', 2.0), ('Wearing', 1.0)]
# Searching --> [('Building_subparts', 13.0), ('Residence', 7.0), ('Contacting', 7.0)]
# Taking --> [('Bringing', 12.0), ('Building_subparts', 8.0), ('Arriving', 7.0)]
