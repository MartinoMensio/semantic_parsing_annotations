# %%
import aligner
# %matplotlib inline

# the table is normalized by rows (each row sums to 1)
aligner.main()
# Out:
# /home/martino/kmi/open-sesame/annotation_playground/aligner.py:103: RuntimeWarning: invalid value encountered in true_divide
#   new_matrix = matrix / row_sums[:, np.newaxis]
